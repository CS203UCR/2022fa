# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *

# %% [markdown]
# # Performance
#
# ## How programmers affects performance?

# %%
render_code("./programmer/madd.c")
# Out:
# // ./programmer/madd.c:1-54 (54 lines)
# #include <stdio.h>
# #include <stdlib.h>
#
# int ARRAY_SIZE = 8192;
#
# int main(int argc, char **argv)
# {
#   int **a, **b, **c, i, j, k;
#   /* initialize a, b */
#   if(argc >= 2)
#     ARRAY_SIZE = atoi(argv[1]);
#   a = (int **)malloc(ARRAY_SIZE*sizeof(int *));
#   for(i = 0; i < ARRAY_SIZE; i++)
#   {
#     a[i] = (int *)malloc(ARRAY_SIZE*sizeof(int));
#     for(j = 0; j < ARRAY_SIZE; j++)
#       a[i][j] = (rand()%100)+1;
#   }
#   b = (int **)malloc(ARRAY_SIZE*sizeof(int *));
#   for(i = 0; i < ARRAY_SIZE; i++)
#   {
#     b[i] = (int *)malloc(ARRAY_SIZE*sizeof(int));
#     for(j = 0; j < ARRAY_SIZE; j++)
#       b[i][j] = (rand()%100)+1;
#   }
#   c = (int **)malloc(ARRAY_SIZE*sizeof(int *));
#   for(i = 0; i < ARRAY_SIZE; i++)
#   {
#     c[i] = (int *)malloc(ARRAY_SIZE*sizeof(int));
#     for(j = 0; j < ARRAY_SIZE; j++)
#       c[i][j] = 0;
#   }
# //  mm(a, b, c);
#   /* Do matrix addition */
# #ifdef A
#     for(i = 0; i < ARRAY_SIZE; i++)
#     {
#       for(j = 0; j < ARRAY_SIZE; j++)
#       {
#         c[i][j] = a[i][j]+b[i][j];
#       }
#     }
# #else
#     for(j = 0; j < ARRAY_SIZE; j++)
#     {
#       for(i = 0; i < ARRAY_SIZE; i++)
#       {
#         c[i][j] = a[i][j]+b[i][j];
#       }
#     }
# #endif
#   printf("%d\n",c[rand()%256][rand()%256]);
#   return 0;
# }

# %%
! cd programmer; make
! time ./programmer/madd_A_O3
! time ./programmer/madd_B_O3
# Out:
# make: Nothing to be done for 'all'.
# 161
#
# real	0m0.876s
# user	0m0.736s
# sys	0m0.140s
# 161
#
# real	0m1.367s
# user	0m1.246s
# sys	0m0.120s

# %% [markdown]
# ## How programming languages affects performance?
#
# ### Python

# %%
render_code("./programming_languages/hello.py")
# Out:
# // ./programming_languages/hello.py:1-1 (1 lines)
# print("Hello, World!")

# %%
# !perf stat python ./programming_languages/hello.py
# Out:
# Hello, World!
#
#  Performance counter stats for 'python ./programming_languages/hello.py':
#
#              23.68 msec task-clock                #    0.254 CPUs utilized
#                  5      context-switches          #  211.181 /sec
#                  1      cpu-migrations            #   42.236 /sec
#              1,004      page-faults               #   42.405 K/sec
#         43,363,116      cycles                    #    1.831 GHz                      (83.17%)
#            126,785      stalled-cycles-frontend   #    0.29% frontend cycles idle     (83.25%)
#            347,445      stalled-cycles-backend    #    0.80% backend cycles idle      (83.13%)
#         67,562,127      instructions              #    1.56  insn per cycle
#                                                   #    0.01  stalled cycles per insn  (86.68%)
#         15,377,753      branches                  #  649.497 M/sec                    (83.30%)
#            660,587      branch-misses             #    4.30% of all branches          (80.47%)
#
#        0.093041573 seconds time elapsed
#
#        0.013878000 seconds user
#        0.010408000 seconds sys

# %% [markdown]
# ### Perl

# %%
render_code("./programming_languages/hello.pl")
# Out:
# // ./programming_languages/hello.pl:1-5 (5 lines)
# #!/usr/bin/perl
# use strict;
# use warnings;
#
# print "Hello, World!\n";

# %%
! perf stat ./programming_languages/hello.pl
# Out:
# Hello, World!
#
#  Performance counter stats for './programming_languages/hello.pl':
#
#               6.90 msec task-clock                #    0.121 CPUs utilized
#                  2      context-switches          #  289.907 /sec
#                  0      cpu-migrations            #    0.000 /sec
#                306      page-faults               #   44.356 K/sec
#          9,226,668      cycles                    #    1.337 GHz                      (46.46%)
#             19,058      stalled-cycles-frontend   #    0.21% frontend cycles idle
#            357,655      stalled-cycles-backend    #    3.88% backend cycles idle
#         12,534,887      instructions              #    1.36  insn per cycle
#                                                   #    0.03  stalled cycles per insn
#          2,589,230      branches                  #  375.318 M/sec
#             77,711      branch-misses             #    3.00% of all branches          (53.54%)
#
#        0.056928115 seconds time elapsed
#
#        0.003828000 seconds user
#        0.003828000 seconds sys

# %% [markdown]
# ### Java

# %%
render_code("./programming_languages/HelloWorld.java")
# Out:
# // ./programming_languages/HelloWorld.java:1-8 (8 lines)
# public class HelloWorld {
#
#     public static void main(String[] args) {
#         // Prints "Hello, World" to the terminal window.
#         System.out.println("Hello, World");
#     }
#
# }

# %%
! cd ./programming_languages/; javac HelloWorld.java
! cd ./programming_languages/; perf stat java HelloWorld
# Out:
# Hello, World
#
#  Performance counter stats for 'java HelloWorld':
#
#              65.78 msec task-clock                #    1.078 CPUs utilized
#                303      context-switches          #    4.606 K/sec
#                 11      cpu-migrations            #  167.219 /sec
#              4,151      page-faults               #   63.102 K/sec
#        154,617,827      cycles                    #    2.350 GHz                      (88.82%)
#            634,139      stalled-cycles-frontend   #    0.41% frontend cycles idle     (76.34%)
#          1,232,124      stalled-cycles-backend    #    0.80% backend cycles idle      (77.88%)
#        154,445,420      instructions              #    1.00  insn per cycle
#                                                   #    0.01  stalled cycles per insn  (84.14%)
#         25,982,527      branches                  #  394.978 M/sec                    (85.36%)
#          1,064,528      branch-misses             #    4.10% of all branches          (87.86%)
#
#        0.061005938 seconds time elapsed
#
#        0.037169000 seconds user
#        0.033039000 seconds sys

# %% [markdown]
# ### Go

# %%
render_code("./programming_languages/hello-world.go")
# Out:
# // ./programming_languages/hello-world.go:1-5 (5 lines)
# package main
# import "fmt"
# func main() {
#     fmt.Println("hello world")
# }

# %%
! perf stat /usr/local/go/bin/go run ./programming_languages/hello-world.go
# Out:
# hello world
#
#  Performance counter stats for '/usr/local/go/bin/go run ./programming_languages/hello-world.go':
#
#             327.16 msec task-clock                #    0.445 CPUs utilized
#              4,299      context-switches          #   13.140 K/sec
#                285      cpu-migrations            #  871.133 /sec
#             16,826      page-faults               #   51.430 K/sec
#        544,150,532      cycles                    #    1.663 GHz                      (84.58%)
#          4,878,342      stalled-cycles-frontend   #    0.90% frontend cycles idle     (87.57%)
#         15,242,873      stalled-cycles-backend    #    2.80% backend cycles idle      (80.87%)
#        848,086,551      instructions              #    1.56  insn per cycle
#                                                   #    0.02  stalled cycles per insn  (82.16%)
#        155,129,613      branches                  #  474.170 M/sec                    (87.60%)
#          2,613,688      branch-misses             #    1.68% of all branches          (84.35%)
#
#        0.735362455 seconds time elapsed
#
#        0.159650000 seconds user
#        0.193418000 seconds sys

# %%
# !/usr/local/go/bin/go build ./programming_languages/hello-world.go
! perf stat ./programming_languages/hello-world
# Out:
# hello world
#
#  Performance counter stats for './programming_languages/hello-world':
#
#               4.26 msec task-clock                #    0.481 CPUs utilized
#                 21      context-switches          #    4.934 K/sec
#                  1      cpu-migrations            #  234.972 /sec
#                196      page-faults               #   46.055 K/sec
#          2,591,150      cycles                    #    0.609 GHz                      (16.51%)
#             27,048      stalled-cycles-frontend   #    1.04% frontend cycles idle
#             29,309      stalled-cycles-backend    #    1.13% backend cycles idle
#          2,202,174      instructions              #    0.85  insn per cycle
#                                                   #    0.01  stalled cycles per insn
#            418,887      branches                  #   98.427 M/sec
#             14,238      branch-misses             #    3.40% of all branches          (83.97%)
#
#        0.008840719 seconds time elapsed
#
#        0.000000000 seconds user
#        0.005706000 seconds sys

# %% [markdown]
# ### C++

# %%
render_code("./programming_languages/hello.cpp")
# Out:
# // ./programming_languages/hello.cpp:1-8 (8 lines)
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     cout << "Hello, World!";
#     return 0;
# }

# %%
! g++ -O4 ./programming_languages/hello.cpp -o ./programming_languages/hello_cpp
! perf stat ./programming_languages/hello_cpp
# Out:
# Hello, World!
#  Performance counter stats for './programming_languages/hello_cpp':
#
#               3.76 msec task-clock                #    0.181 CPUs utilized
#                  1      context-switches          #  265.704 /sec
#                  0      cpu-migrations            #    0.000 /sec
#                123      page-faults               #   32.682 K/sec
#          2,388,461      cycles                    #    0.635 GHz                      (45.58%)
#             10,089      stalled-cycles-frontend   #    0.42% frontend cycles idle
#            106,352      stalled-cycles-backend    #    4.45% backend cycles idle
#          3,650,926      instructions              #    1.53  insn per cycle
#                                                   #    0.03  stalled cycles per insn
#            622,646      branches                  #  165.439 M/sec
#             18,876      branch-misses             #    3.03% of all branches          (54.42%)
#
#        0.020754384 seconds time elapsed
#
#        0.000000000 seconds user
#        0.004826000 seconds sys

# %% [markdown]
# ### C

# %%
render_code("./programming_languages/hello.c")
# Out:
# // ./programming_languages/hello.c:1-7 (7 lines)
# #include <stdio.h>
#
# int main()
# {
#     printf("Hello, world!\n");
#     return 0;
# }

# %%
! gcc -O4 ./programming_languages/hello.c -o ./programming_languages/hello_c
! perf stat ./programming_languages/hello_c
# Out:
# Hello, world!
#
#  Performance counter stats for './programming_languages/hello_c':
#
#               1.08 msec task-clock                #    0.051 CPUs utilized
#                  1      context-switches          #  928.245 /sec
#                  0      cpu-migrations            #    0.000 /sec
#                 50      page-faults               #   46.412 K/sec
#            807,323      cycles                    #    0.749 GHz
#              5,550      stalled-cycles-frontend   #    0.69% frontend cycles idle
#             40,699      stalled-cycles-backend    #    5.04% backend cycles idle
#            800,338      instructions              #    0.99  insn per cycle
#                                                   #    0.05  stalled cycles per insn
#            162,175      branches                  #  150.538 M/sec
#      <not counted>      branch-misses                                                 (0.00%)
#
#        0.021036123 seconds time elapsed
#
#        0.000000000 seconds user
#        0.002385000 seconds sys
#
#
# Some events weren't counted. Try disabling the NMI watchdog:
# 	echo 0 > /proc/sys/kernel/nmi_watchdog
# 	perf stat ...
# 	echo 1 > /proc/sys/kernel/nmi_watchdog
